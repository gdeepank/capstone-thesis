# %%
# Importing required libraries

import pandas as pd
import numpy as np
import cv2
from matplotlib import image as im
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
import tensorflow as tf
from keras import models
from keras.models import load_model
from keras import optimizers
import keras.backend as K
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.layers.core import Dense
# Out:
# Using TensorFlow backend.

# %%
# Reading the dataset

data = pd.read_csv("C:/Users/Deepank/OneDrive/Documents/PES University/Capstone/progress/dataset - New.csv")
print("No. of columns in the dataset: ", data.shape[1])
print("No. of rows in the dataset: ", data.shape[0])
# Out:
# No. of columns in the dataset:  7
# No. of rows in the dataset:  240

# %%
# Understanding the dataset

data.head()
# Out:
#                                               Images                Disease  \
# 0  ./Bacterial leaf blight/Bacterial_leaf_blight_...  Bacterial leaf blight
# 1  ./Bacterial leaf blight/Bacterial_leaf_blight_...  Bacterial leaf blight
# 2  ./Bacterial leaf blight/Bacterial_leaf_blight_...  Bacterial leaf blight
# 3  ./Bacterial leaf blight/Bacterial_leaf_blight_...  Bacterial leaf blight
# 4  ./Bacterial leaf blight/Bacterial_leaf_blight_...  Bacterial leaf blight
#
#                                    Dicom Images  Xmin Ymin  Xmax Ymax
# 0   ./segmented-blb/Bacterial_leaf_blight_1.dcm   858  362  1733  556
# 1  ./segmented-blb/Bacterial_leaf_blight_10.dcm   764  423  2414  581
# 2  ./segmented-blb/Bacterial_leaf_blight_11.dcm     3  462  2278  652
# 3  ./segmented-blb/Bacterial_leaf_blight_12.dcm  1147  439  2466  564
# 4  ./segmented-blb/Bacterial_leaf_blight_13.dcm   849  368  1758  579

# %%
data.tail()
# Out:
#                            Images    Disease                     Dicom Images  \
# 235   ./Leaf smut/Leaf_smut_6.jpg  Leaf smut   ./segmented-ls/Leaf_smut_6.dcm
# 236  ./Leaf smut/Leaf_smut_60.jpg  Leaf smut  ./segmented-ls/Leaf_smut_60.dcm
# 237   ./Leaf smut/Leaf_smut_7.jpg  Leaf smut   ./segmented-ls/Leaf_smut_7.dcm
# 238   ./Leaf smut/Leaf_smut_8.jpg  Leaf smut   ./segmented-ls/Leaf_smut_8.dcm
# 239   ./Leaf smut/Leaf_smut_9.jpg  Leaf smut   ./segmented-ls/Leaf_smut_9.dcm
#
#      Xmin Ymin  Xmax Ymax
# 235  1272  358  2360  595
# 236   227  313  2447  679
# 237   356  349  2812  727
# 238   266  139  2845  679
# 239   310  366  1260  695

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Images        240 non-null    object
#  1   Disease       240 non-null    object
#  2   Dicom Images  240 non-null    object
#  3   Xmin          240 non-null    object
#  4   Ymin          240 non-null    object
#  5   Xmax          240 non-null    object
#  6   Ymax          240 non-null    object
# dtypes: object(7)
# memory usage: 13.2+ KB

# %%
# Performing feature engineering 

data['Disease'].value_counts()
# Out:
# Bacterial leaf blight    60
# Healthy leaf             60
# Brown spot               60
# Leaf smut                60
# Name: Disease, dtype: int64

# %%
data[data.Disease=="Healthy leaf"].head()
# Out:
#                                  Images       Disease  \
# 120   ./Healthy leaf/Healthy_leaf_1.jpg  Healthy leaf
# 121  ./Healthy leaf/Healthy_leaf_10.jpg  Healthy leaf
# 122  ./Healthy leaf/Healthy_leaf_11.jpg  Healthy leaf
# 123  ./Healthy leaf/Healthy_leaf_12.jpg  Healthy leaf
# 124  ./Healthy leaf/Healthy_leaf_13.jpg  Healthy leaf
#
#                            Dicom Images Xmin Ymin Xmax Ymax
# 120   ./segmented-hl/Healthy_leaf_1.dcm    ?    ?    ?    ?
# 121  ./segmented-hl/Healthy_leaf_10.dcm    ?    ?    ?    ?
# 122  ./segmented-hl/Healthy_leaf_11.dcm    ?    ?    ?    ?
# 123  ./segmented-hl/Healthy_leaf_12.dcm    ?    ?    ?    ?
# 124  ./segmented-hl/Healthy_leaf_13.dcm    ?    ?    ?    ?

# %%
data = data[data.Disease!="Healthy leaf"]
data.reset_index(drop=True, inplace=True)

# %%
data.Xmax = data.Xmax.astype("int64")
data.Ymax = data.Ymax.astype("int64")
data.Xmin = data.Xmin.astype("int64")
data.Ymin = data.Ymin.astype("int64")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Images        180 non-null    object
#  1   Disease       180 non-null    object
#  2   Dicom Images  180 non-null    object
#  3   Xmin          180 non-null    int64
#  4   Ymin          180 non-null    int64
#  5   Xmax          180 non-null    int64
#  6   Ymax          180 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 10.0+ KB

# %%
# Splitting the dataset into train and test

ratio = int(0.8 * data.shape[0])
indices = np.random.permutation(data.shape[0])
training_idx, test_idx = indices[:ratio], indices[ratio:]
train, test = data.iloc[training_idx,:], data.iloc[test_idx,:]

train.reset_index(drop=True, inplace=True)
test.reset_index(drop=True, inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Images        144 non-null    object
#  1   Disease       144 non-null    object
#  2   Dicom Images  144 non-null    object
#  3   Xmin          144 non-null    int64
#  4   Ymin          144 non-null    int64
#  5   Xmax          144 non-null    int64
#  6   Ymax          144 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 8.0+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Images        36 non-null     object
#  1   Disease       36 non-null     object
#  2   Dicom Images  36 non-null     object
#  3   Xmin          36 non-null     int64
#  4   Ymin          36 non-null     int64
#  5   Xmax          36 non-null     int64
#  6   Ymax          36 non-null     int64
# dtypes: int64(4), object(3)
# memory usage: 2.1+ KB

# %%
# Function to normalize bounding box coordinates (PASCAL VOC format)

def normalize(box):             # box -> (xmin, ymin, xmax, ymax)
    x1 = box[0] / 224
    y1 = box[1] / 224
    x2 = box[2] / 224
    y2 = box[3] / 224
    return (x1, y1, x2, y2)

# %%
# Preparing training dataset labels for input

labels = np.zeros(shape = (len(train), 4))

for i in range(len(train)):
    box = (train['Xmin'][i], train['Ymin'][i], train['Xmax'][i], train['Ymax'][i])
    bb = normalize(box) 
    labels[i] = [bb[0], bb[1], bb[2], bb[3]]

# %%
# Preparing test dataset labels for evaluation

val_labels = np.zeros(shape = (len(test), 4))

for i in range(len(test)):
    box = (test['Xmin'][i], test['Ymin'][i], test['Xmax'][i], test['Ymax'][i])
    bb = normalize(box) 
    val_labels[i] = [bb[0], bb[1], bb[2], bb[3]]

# %%
# Loading the pre-trained model 

model = VGG16(weights='imagenet', include_top=False)

# %%
# Variable initialisation for model training and evaluation

train_feature = np.zeros(shape = (len(train), 7, 7, 512)) # Last layer of VGG16 has a shape of 7 x 7 x 512
test_feature = np.zeros(shape = (len(test), 7, 7, 512))

# %%
# Feature extraction of training set images

for i in range(len(train)):
    img_path = train.Images[i]
    img = cv2.imread(img_path)
    img_data = cv2.resize(img, (224,224))
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    vgg16_feature = model.predict(img_data)
    train_feature[i] = vgg16_feature

# %%
# Feature extraction of test set images

for i in range(len(test)):
    img_path = test.Images[i]
    img = cv2.imread(img_path)
    img_data = cv2.resize(img, (224,224))
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    vgg16_feature = model.predict(img_data)
    test_feature[i] = vgg16_feature

# %%
train_features_vec = np.reshape(train_feature, (len(train), 7 * 7 * 512))
print("Train features of the image: {}".format(train_features_vec.shape))

test_features_vec = np.reshape(test_feature, (len(test), 7 * 7 * 512))
print("Train features of the image: {}".format(test_features_vec.shape))
# Out:
# Train features of the image: (144, 25088)
# Train features of the image: (36, 25088)

# %%
# Defining functions for calculating the model loss and accuracy

def calculate_iou(target, pred):
    xA = K.maximum(target[:,0], pred[:,0])
    yA = K.maximum(target[:,1], pred[:,1])
    xB = K.minimum(target[:,2], pred[:,2])
    yB = K.minimum(target[:,3], pred[:,3])
    interArea = K.maximum(0.0, xB-xA+1) * K.maximum(0.0, yB-yA+1)
    boxAarea = (target[:,2]-target[:,0]+1) * (target[:,3]-target[:,1]+1)
    boxBarea = (pred[:,2]-pred[:,0]+1) * (pred[:,3]-pred[:,1]+1)
    iou = interArea / float(boxAarea + boxBarea - interArea)
    return iou

def custom_loss(y_true, y_pred):
    mse = tf.losses.mean_squared_error(y_true, y_pred)
    iou = calculate_iou(y_true , y_pred)
    return mse + (1-iou)

def iou_metric(y_true, y_pred):
    return calculate_iou(y_true, y_pred)

# %%
# Modifying and re-using the saved new neural network model

new_model = load_model("mymodel.h5")
new_model.pop()
new_model.add(Dense(4, activation='linear', name="last_layer"))

# %%
new_model.compile(optimizer=optimizers.Adam(0.0001), loss=custom_loss, metrics=[iou_metric])

# %%
# Model training and validation

history = new_model.fit(train_features_vec, labels, validation_data=(test_features_vec, val_labels), epochs=400)
# Out:
# Epoch 1/400
# 5/5 [==============================] - 1s 222ms/step - loss: 223.9023 - iou_metric: 0.0067 - val_loss: 54.6159 - val_iou_metric: 0.0155
# Epoch 2/400
# 5/5 [==============================] - 1s 113ms/step - loss: 190.4682 - iou_metric: 0.0086 - val_loss: 51.2009 - val_iou_metric: 0.0079
# Epoch 3/400
# 5/5 [==============================] - 1s 117ms/step - loss: 135.6956 - iou_metric: 0.0103 - val_loss: 41.2276 - val_iou_metric: 0.0431
# Epoch 4/400
# 5/5 [==============================] - 1s 114ms/step - loss: 102.8116 - iou_metric: 0.0131 - val_loss: 37.8997 - val_iou_metric: 0.0571
# Epoch 5/400
# 5/5 [==============================] - 1s 112ms/step - loss: 77.5245 - iou_metric: 0.0195 - val_loss: 29.5686 - val_iou_metric: 0.0605
# Epoch 6/400
# 5/5 [==============================] - 1s 116ms/step - loss: 66.5941 - iou_metric: 0.0275 - val_loss: 24.1108 - val_iou_metric: 0.0571
# Epoch 7/400
# 5/5 [==============================] - 1s 117ms/step - loss: 39.7734 - iou_metric: 0.0334 - val_loss: 18.8471 - val_iou_metric: 0.0786
# Epoch 8/400
# 5/5 [==============================] - 1s 115ms/step - loss: 43.1335 - iou_metric: 0.0584 - val_loss: 17.5738 - val_iou_metric: 0.0883
# Epoch 9/400
# 5/5 [==============================] - 1s 113ms/step - loss: 31.7902 - iou_metric: 0.0786 - val_loss: 15.8569 - val_iou_metric: 0.0972
# Epoch 10/400
# 5/5 [==============================] - 1s 114ms/step - loss: 21.2321 - iou_metric: 0.1003 - val_loss: 15.9495 - val_iou_metric: 0.1003
# Epoch 11/400
# 5/5 [==============================] - 1s 116ms/step - loss: 18.9732 - iou_metric: 0.0898 - val_loss: 15.7246 - val_iou_metric: 0.0967
# Epoch 12/400
# 5/5 [==============================] - 1s 115ms/step - loss: 16.3292 - iou_metric: 0.0874 - val_loss: 14.7287 - val_iou_metric: 0.1057
# Epoch 13/400
# 5/5 [==============================] - 1s 117ms/step - loss: 16.6619 - iou_metric: 0.1063 - val_loss: 13.2289 - val_iou_metric: 0.1156
# Epoch 14/400
# 5/5 [==============================] - 1s 118ms/step - loss: 14.0563 - iou_metric: 0.1187 - val_loss: 12.1642 - val_iou_metric: 0.1274
# Epoch 15/400
# 5/5 [==============================] - 1s 119ms/step - loss: 10.7522 - iou_metric: 0.1205 - val_loss: 11.4055 - val_iou_metric: 0.1283
# Epoch 16/400
# 5/5 [==============================] - 1s 117ms/step - loss: 14.2108 - iou_metric: 0.1324 - val_loss: 11.0868 - val_iou_metric: 0.1215
# Epoch 17/400
# 5/5 [==============================] - 1s 115ms/step - loss: 11.0812 - iou_metric: 0.1428 - val_loss: 10.8685 - val_iou_metric: 0.1212
# Epoch 18/400
# 5/5 [==============================] - 1s 119ms/step - loss: 12.8255 - iou_metric: 0.1143 - val_loss: 11.0475 - val_iou_metric: 0.1281
# Epoch 19/400
# 5/5 [==============================] - 1s 117ms/step - loss: 9.6933 - iou_metric: 0.1455 - val_loss: 11.1252 - val_iou_metric: 0.1286
# Epoch 20/400
# 5/5 [==============================] - 1s 118ms/step - loss: 10.4889 - iou_metric: 0.1283 - val_loss: 11.5084 - val_iou_metric: 0.1224
# Epoch 21/400
# 5/5 [==============================] - 1s 119ms/step - loss: 7.4576 - iou_metric: 0.1298 - val_loss: 11.5597 - val_iou_metric: 0.1359
# Epoch 22/400
# 5/5 [==============================] - 1s 115ms/step - loss: 8.8477 - iou_metric: 0.1726 - val_loss: 11.2638 - val_iou_metric: 0.1560
# Epoch 23/400
# 5/5 [==============================] - 1s 116ms/step - loss: 7.9580 - iou_metric: 0.1310 - val_loss: 10.7540 - val_iou_metric: 0.1776
# Epoch 24/400
# 5/5 [==============================] - 1s 116ms/step - loss: 8.6820 - iou_metric: 0.1760 - val_loss: 10.2886 - val_iou_metric: 0.1799
# Epoch 25/400
# 5/5 [==============================] - 1s 118ms/step - loss: 6.6338 - iou_metric: 0.1723 - val_loss: 10.2000 - val_iou_metric: 0.1733
# Epoch 26/400
# 5/5 [==============================] - 1s 121ms/step - loss: 7.0121 - iou_metric: 0.1652 - val_loss: 10.1122 - val_iou_metric: 0.1692
# Epoch 27/400
# 5/5 [==============================] - 1s 116ms/step - loss: 6.8486 - iou_metric: 0.1802 - val_loss: 9.9486 - val_iou_metric: 0.1790
# Epoch 28/400
# 5/5 [==============================] - 1s 117ms/step - loss: 6.0832 - iou_metric: 0.1919 - val_loss: 10.1025 - val_iou_metric: 0.1803
# Epoch 29/400
# 5/5 [==============================] - 1s 117ms/step - loss: 6.0342 - iou_metric: 0.1815 - val_loss: 10.2984 - val_iou_metric: 0.1755
# Epoch 30/400
# 5/5 [==============================] - 1s 115ms/step - loss: 6.3337 - iou_metric: 0.1737 - val_loss: 10.4445 - val_iou_metric: 0.1644
# Epoch 31/400
# 5/5 [==============================] - 1s 124ms/step - loss: 5.9282 - iou_metric: 0.2013 - val_loss: 10.3006 - val_iou_metric: 0.1631
# Epoch 32/400
# 5/5 [==============================] - 1s 116ms/step - loss: 5.7073 - iou_metric: 0.2039 - val_loss: 10.1419 - val_iou_metric: 0.1722
# Epoch 33/400
# 5/5 [==============================] - 1s 117ms/step - loss: 5.6243 - iou_metric: 0.1707 - val_loss: 10.0362 - val_iou_metric: 0.1921
# Epoch 34/400
# 5/5 [==============================] - 1s 117ms/step - loss: 5.1387 - iou_metric: 0.2138 - val_loss: 9.8796 - val_iou_metric: 0.1990
# Epoch 35/400
# 5/5 [==============================] - 1s 115ms/step - loss: 4.7119 - iou_metric: 0.2269 - val_loss: 10.0518 - val_iou_metric: 0.1908
# Epoch 36/400
# 5/5 [==============================] - 1s 121ms/step - loss: 5.5748 - iou_metric: 0.2004 - val_loss: 10.3647 - val_iou_metric: 0.1743
# Epoch 37/400
# 5/5 [==============================] - 1s 117ms/step - loss: 5.2709 - iou_metric: 0.1951 - val_loss: 10.2112 - val_iou_metric: 0.1817
# Epoch 38/400
# 5/5 [==============================] - 1s 117ms/step - loss: 5.0642 - iou_metric: 0.2242 - val_loss: 9.9124 - val_iou_metric: 0.1830
# Epoch 39/400
# 5/5 [==============================] - 1s 117ms/step - loss: 5.0441 - iou_metric: 0.2026 - val_loss: 9.8137 - val_iou_metric: 0.1694
# Epoch 40/400
# 5/5 [==============================] - 1s 118ms/step - loss: 4.8487 - iou_metric: 0.2278 - val_loss: 9.7447 - val_iou_metric: 0.1598
# Epoch 41/400
# 5/5 [==============================] - 1s 114ms/step - loss: 4.6407 - iou_metric: 0.2183 - val_loss: 9.5022 - val_iou_metric: 0.1761
# Epoch 42/400
# 5/5 [==============================] - 1s 118ms/step - loss: 4.2192 - iou_metric: 0.2532 - val_loss: 9.3127 - val_iou_metric: 0.2041
# Epoch 43/400
# 5/5 [==============================] - 1s 119ms/step - loss: 5.0551 - iou_metric: 0.2351 - val_loss: 9.0922 - val_iou_metric: 0.1981
# Epoch 44/400
# 5/5 [==============================] - 1s 114ms/step - loss: 4.8895 - iou_metric: 0.2180 - val_loss: 9.2964 - val_iou_metric: 0.1830
# Epoch 45/400
# 5/5 [==============================] - 1s 111ms/step - loss: 4.5670 - iou_metric: 0.2269 - val_loss: 9.5493 - val_iou_metric: 0.1935
# Epoch 46/400
# 5/5 [==============================] - 1s 116ms/step - loss: 4.0771 - iou_metric: 0.2452 - val_loss: 9.4551 - val_iou_metric: 0.2101
# Epoch 47/400
# 5/5 [==============================] - 1s 113ms/step - loss: 4.7169 - iou_metric: 0.2259 - val_loss: 9.2683 - val_iou_metric: 0.2223
# Epoch 48/400
# 5/5 [==============================] - 1s 112ms/step - loss: 4.5126 - iou_metric: 0.2262 - val_loss: 9.3625 - val_iou_metric: 0.2258
# Epoch 49/400
# 5/5 [==============================] - 1s 117ms/step - loss: 4.6200 - iou_metric: 0.2388 - val_loss: 9.3248 - val_iou_metric: 0.2213
# Epoch 50/400
# 5/5 [==============================] - 1s 116ms/step - loss: 4.3767 - iou_metric: 0.2371 - val_loss: 9.3099 - val_iou_metric: 0.2124
# Epoch 51/400
# 5/5 [==============================] - 1s 115ms/step - loss: 4.4772 - iou_metric: 0.2656 - val_loss: 9.1880 - val_iou_metric: 0.2197
# Epoch 52/400
# 5/5 [==============================] - 1s 115ms/step - loss: 4.0425 - iou_metric: 0.2672 - val_loss: 9.2367 - val_iou_metric: 0.2171
# Epoch 53/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.8911 - iou_metric: 0.2641 - val_loss: 9.4075 - val_iou_metric: 0.2075
# Epoch 54/400
# 5/5 [==============================] - 1s 115ms/step - loss: 4.0085 - iou_metric: 0.2769 - val_loss: 9.5754 - val_iou_metric: 0.2064
# Epoch 55/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.9005 - iou_metric: 0.2643 - val_loss: 9.7377 - val_iou_metric: 0.2081
# Epoch 56/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.9292 - iou_metric: 0.2658 - val_loss: 9.6404 - val_iou_metric: 0.2078
# Epoch 57/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.8331 - iou_metric: 0.2759 - val_loss: 9.5569 - val_iou_metric: 0.2099
# Epoch 58/400
# 5/5 [==============================] - 1s 111ms/step - loss: 4.2413 - iou_metric: 0.2839 - val_loss: 9.5705 - val_iou_metric: 0.1954
# Epoch 59/400
# 5/5 [==============================] - 1s 110ms/step - loss: 4.4263 - iou_metric: 0.2593 - val_loss: 9.5025 - val_iou_metric: 0.1790
# Epoch 60/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.7688 - iou_metric: 0.2635 - val_loss: 9.3692 - val_iou_metric: 0.1770
# Epoch 61/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.9668 - iou_metric: 0.2672 - val_loss: 9.3523 - val_iou_metric: 0.1766
# Epoch 62/400
# 5/5 [==============================] - 1s 111ms/step - loss: 4.0875 - iou_metric: 0.2692 - val_loss: 9.1624 - val_iou_metric: 0.1904
# Epoch 63/400
# 5/5 [==============================] - 1s 113ms/step - loss: 4.0899 - iou_metric: 0.2522 - val_loss: 9.0093 - val_iou_metric: 0.1986
# Epoch 64/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.3777 - iou_metric: 0.2700 - val_loss: 9.0195 - val_iou_metric: 0.1983
# Epoch 65/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.7968 - iou_metric: 0.2908 - val_loss: 9.1383 - val_iou_metric: 0.1948
# Epoch 66/400
# 5/5 [==============================] - 1s 111ms/step - loss: 4.1968 - iou_metric: 0.2765 - val_loss: 9.1059 - val_iou_metric: 0.2003
# Epoch 67/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.8998 - iou_metric: 0.3119 - val_loss: 9.0104 - val_iou_metric: 0.2094
# Epoch 68/400
# 5/5 [==============================] - 1s 109ms/step - loss: 3.9044 - iou_metric: 0.2665 - val_loss: 9.2207 - val_iou_metric: 0.1951
# Epoch 69/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.6103 - iou_metric: 0.2897 - val_loss: 9.1392 - val_iou_metric: 0.2073
# Epoch 70/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.6209 - iou_metric: 0.2858 - val_loss: 8.8788 - val_iou_metric: 0.2186
# Epoch 71/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.3587 - iou_metric: 0.2911 - val_loss: 8.7484 - val_iou_metric: 0.2117
# Epoch 72/400
# 5/5 [==============================] - 1s 109ms/step - loss: 4.1304 - iou_metric: 0.2807 - val_loss: 8.5323 - val_iou_metric: 0.2198
# Epoch 73/400
# 5/5 [==============================] - 1s 114ms/step - loss: 4.0571 - iou_metric: 0.2798 - val_loss: 8.7176 - val_iou_metric: 0.2139
# Epoch 74/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.6769 - iou_metric: 0.3089 - val_loss: 9.0452 - val_iou_metric: 0.2106
# Epoch 75/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.7297 - iou_metric: 0.2745 - val_loss: 8.9453 - val_iou_metric: 0.2201
# Epoch 76/400
# 5/5 [==============================] - 1s 110ms/step - loss: 4.3391 - iou_metric: 0.2824 - val_loss: 8.8594 - val_iou_metric: 0.2290
# Epoch 77/400
# 5/5 [==============================] - 1s 115ms/step - loss: 4.0443 - iou_metric: 0.2707 - val_loss: 9.1273 - val_iou_metric: 0.2200
# Epoch 78/400
# 5/5 [==============================] - 1s 111ms/step - loss: 4.1222 - iou_metric: 0.2869 - val_loss: 9.2831 - val_iou_metric: 0.2087
# Epoch 79/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.5660 - iou_metric: 0.2979 - val_loss: 9.0506 - val_iou_metric: 0.2227
# Epoch 80/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.7331 - iou_metric: 0.2909 - val_loss: 8.9769 - val_iou_metric: 0.2186
# Epoch 81/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.5038 - iou_metric: 0.2798 - val_loss: 8.9606 - val_iou_metric: 0.2165
# Epoch 82/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.9566 - iou_metric: 0.2978 - val_loss: 8.4866 - val_iou_metric: 0.2394
# Epoch 83/400
# 5/5 [==============================] - 1s 109ms/step - loss: 3.8878 - iou_metric: 0.2796 - val_loss: 8.2161 - val_iou_metric: 0.2490
# Epoch 84/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.8277 - iou_metric: 0.2849 - val_loss: 8.3511 - val_iou_metric: 0.2232
# Epoch 85/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.6390 - iou_metric: 0.2889 - val_loss: 8.5442 - val_iou_metric: 0.2037
# Epoch 86/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.7894 - iou_metric: 0.2940 - val_loss: 8.2470 - val_iou_metric: 0.2202
# Epoch 87/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.9521 - iou_metric: 0.2858 - val_loss: 8.0767 - val_iou_metric: 0.2282
# Epoch 88/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.4842 - iou_metric: 0.3019 - val_loss: 8.2009 - val_iou_metric: 0.2178
# Epoch 89/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.6666 - iou_metric: 0.2839 - val_loss: 8.0612 - val_iou_metric: 0.2277
# Epoch 90/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.8674 - iou_metric: 0.3004 - val_loss: 7.7491 - val_iou_metric: 0.2435
# Epoch 91/400
# 5/5 [==============================] - 1s 113ms/step - loss: 4.0966 - iou_metric: 0.2751 - val_loss: 7.7741 - val_iou_metric: 0.2380
# Epoch 92/400
# 5/5 [==============================] - 1s 109ms/step - loss: 3.4447 - iou_metric: 0.3032 - val_loss: 7.6908 - val_iou_metric: 0.2454
# Epoch 93/400
# 5/5 [==============================] - 1s 111ms/step - loss: 4.0984 - iou_metric: 0.3099 - val_loss: 7.7844 - val_iou_metric: 0.2471
# Epoch 94/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.8941 - iou_metric: 0.3091 - val_loss: 7.8549 - val_iou_metric: 0.2429
# Epoch 95/400
# 5/5 [==============================] - 1s 109ms/step - loss: 3.8904 - iou_metric: 0.3020 - val_loss: 7.7912 - val_iou_metric: 0.2359
# Epoch 96/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.9001 - iou_metric: 0.3187 - val_loss: 7.8327 - val_iou_metric: 0.2333
# Epoch 97/400
# 5/5 [==============================] - 1s 113ms/step - loss: 4.0117 - iou_metric: 0.3011 - val_loss: 8.2419 - val_iou_metric: 0.2127
# Epoch 98/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.6952 - iou_metric: 0.3107 - val_loss: 8.0780 - val_iou_metric: 0.2225
# Epoch 99/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.8807 - iou_metric: 0.3039 - val_loss: 7.9399 - val_iou_metric: 0.2343
# Epoch 100/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.7122 - iou_metric: 0.3003 - val_loss: 7.9304 - val_iou_metric: 0.2297
# Epoch 101/400
# 5/5 [==============================] - 1s 118ms/step - loss: 4.0832 - iou_metric: 0.3044 - val_loss: 7.9652 - val_iou_metric: 0.2303
# Epoch 102/400
# 5/5 [==============================] - 1s 114ms/step - loss: 4.1218 - iou_metric: 0.2977 - val_loss: 7.8677 - val_iou_metric: 0.2340
# Epoch 103/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.7119 - iou_metric: 0.3298 - val_loss: 7.9335 - val_iou_metric: 0.2335
# Epoch 104/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.4882 - iou_metric: 0.3170 - val_loss: 7.7663 - val_iou_metric: 0.2216
# Epoch 105/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.9875 - iou_metric: 0.2997 - val_loss: 7.6279 - val_iou_metric: 0.2266
# Epoch 106/400
# 5/5 [==============================] - 1s 111ms/step - loss: 4.0708 - iou_metric: 0.3059 - val_loss: 7.5499 - val_iou_metric: 0.2384
# Epoch 107/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.7464 - iou_metric: 0.3137 - val_loss: 7.6682 - val_iou_metric: 0.2351
# Epoch 108/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.8504 - iou_metric: 0.3163 - val_loss: 7.6550 - val_iou_metric: 0.2379
# Epoch 109/400
# 5/5 [==============================] - 1s 116ms/step - loss: 4.6531 - iou_metric: 0.2935 - val_loss: 7.8539 - val_iou_metric: 0.2234
# Epoch 110/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.3915 - iou_metric: 0.3298 - val_loss: 7.9053 - val_iou_metric: 0.2122
# Epoch 111/400
# 5/5 [==============================] - 1s 120ms/step - loss: 3.7995 - iou_metric: 0.2941 - val_loss: 7.7436 - val_iou_metric: 0.2229
# Epoch 112/400
# 5/5 [==============================] - 1s 134ms/step - loss: 3.9086 - iou_metric: 0.3085 - val_loss: 7.7457 - val_iou_metric: 0.2229
# Epoch 113/400
# 5/5 [==============================] - 1s 128ms/step - loss: 4.0388 - iou_metric: 0.3016 - val_loss: 7.6465 - val_iou_metric: 0.2280
# Epoch 114/400
# 5/5 [==============================] - 1s 123ms/step - loss: 3.3794 - iou_metric: 0.3514 - val_loss: 7.3952 - val_iou_metric: 0.2483
# Epoch 115/400
# 5/5 [==============================] - 1s 131ms/step - loss: 3.3693 - iou_metric: 0.3442 - val_loss: 7.3407 - val_iou_metric: 0.2555
# Epoch 116/400
# 5/5 [==============================] - 1s 119ms/step - loss: 3.5725 - iou_metric: 0.3264 - val_loss: 7.5671 - val_iou_metric: 0.2441
# Epoch 117/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.9904 - iou_metric: 0.3318 - val_loss: 7.4517 - val_iou_metric: 0.2398
# Epoch 118/400
# 5/5 [==============================] - 1s 117ms/step - loss: 4.0918 - iou_metric: 0.3030 - val_loss: 7.1430 - val_iou_metric: 0.2415
# Epoch 119/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.7528 - iou_metric: 0.3059 - val_loss: 7.1383 - val_iou_metric: 0.2253
# Epoch 120/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.5258 - iou_metric: 0.2997 - val_loss: 7.2319 - val_iou_metric: 0.2168
# Epoch 121/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.7991 - iou_metric: 0.2970 - val_loss: 6.9364 - val_iou_metric: 0.2397
# Epoch 122/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.8921 - iou_metric: 0.3299 - val_loss: 6.8871 - val_iou_metric: 0.2448
# Epoch 123/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.5196 - iou_metric: 0.3417 - val_loss: 7.2007 - val_iou_metric: 0.2245
# Epoch 124/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.5954 - iou_metric: 0.3615 - val_loss: 7.6008 - val_iou_metric: 0.1992
# Epoch 125/400
# 5/5 [==============================] - 1s 113ms/step - loss: 4.0214 - iou_metric: 0.3227 - val_loss: 7.2488 - val_iou_metric: 0.2026
# Epoch 126/400
# 5/5 [==============================] - 1s 118ms/step - loss: 4.3279 - iou_metric: 0.2813 - val_loss: 7.1309 - val_iou_metric: 0.2120
# Epoch 127/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.7150 - iou_metric: 0.3454 - val_loss: 7.2182 - val_iou_metric: 0.2315
# Epoch 128/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.6822 - iou_metric: 0.3160 - val_loss: 7.2727 - val_iou_metric: 0.2555
# Epoch 129/400
# 5/5 [==============================] - 1s 113ms/step - loss: 4.1809 - iou_metric: 0.2974 - val_loss: 7.0596 - val_iou_metric: 0.2769
# Epoch 130/400
# 5/5 [==============================] - 1s 109ms/step - loss: 3.7935 - iou_metric: 0.3386 - val_loss: 6.8851 - val_iou_metric: 0.2891
# Epoch 131/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.7902 - iou_metric: 0.3116 - val_loss: 6.8492 - val_iou_metric: 0.2878
# Epoch 132/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.7679 - iou_metric: 0.3224 - val_loss: 7.2152 - val_iou_metric: 0.2806
# Epoch 133/400
# 5/5 [==============================] - 1s 114ms/step - loss: 4.4467 - iou_metric: 0.3091 - val_loss: 7.4590 - val_iou_metric: 0.2650
# Epoch 134/400
# 5/5 [==============================] - 1s 110ms/step - loss: 4.1090 - iou_metric: 0.2990 - val_loss: 6.9617 - val_iou_metric: 0.2819
# Epoch 135/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.5908 - iou_metric: 0.3242 - val_loss: 6.9243 - val_iou_metric: 0.2881
# Epoch 136/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.9884 - iou_metric: 0.3436 - val_loss: 7.1180 - val_iou_metric: 0.2718
# Epoch 137/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.9627 - iou_metric: 0.3066 - val_loss: 7.3652 - val_iou_metric: 0.2545
# Epoch 138/400
# 5/5 [==============================] - 1s 110ms/step - loss: 4.0283 - iou_metric: 0.3093 - val_loss: 6.7458 - val_iou_metric: 0.2729
# Epoch 139/400
# 5/5 [==============================] - 1s 113ms/step - loss: 4.0046 - iou_metric: 0.3437 - val_loss: 6.8168 - val_iou_metric: 0.2525
# Epoch 140/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.6609 - iou_metric: 0.3053 - val_loss: 7.3228 - val_iou_metric: 0.2148
# Epoch 141/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.9428 - iou_metric: 0.2777 - val_loss: 6.9070 - val_iou_metric: 0.2246
# Epoch 142/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.6321 - iou_metric: 0.3255 - val_loss: 6.8107 - val_iou_metric: 0.2399
# Epoch 143/400
# 5/5 [==============================] - 1s 113ms/step - loss: 4.3844 - iou_metric: 0.3325 - val_loss: 7.0895 - val_iou_metric: 0.2352
# Epoch 144/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.6967 - iou_metric: 0.3193 - val_loss: 7.1480 - val_iou_metric: 0.2446
# Epoch 145/400
# 5/5 [==============================] - 1s 113ms/step - loss: 4.2470 - iou_metric: 0.3232 - val_loss: 6.9899 - val_iou_metric: 0.2526
# Epoch 146/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.7483 - iou_metric: 0.3255 - val_loss: 7.1747 - val_iou_metric: 0.2403
# Epoch 147/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.8118 - iou_metric: 0.3173 - val_loss: 7.1823 - val_iou_metric: 0.2360
# Epoch 148/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.5265 - iou_metric: 0.3231 - val_loss: 6.7975 - val_iou_metric: 0.2518
# Epoch 149/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.5339 - iou_metric: 0.3292 - val_loss: 6.8475 - val_iou_metric: 0.2581
# Epoch 150/400
# 5/5 [==============================] - 1s 115ms/step - loss: 4.0054 - iou_metric: 0.3354 - val_loss: 7.1104 - val_iou_metric: 0.2465
# Epoch 151/400
# 5/5 [==============================] - 1s 108ms/step - loss: 3.8998 - iou_metric: 0.3324 - val_loss: 7.3868 - val_iou_metric: 0.2247
# Epoch 152/400
# 5/5 [==============================] - 1s 113ms/step - loss: 4.0258 - iou_metric: 0.3163 - val_loss: 7.0560 - val_iou_metric: 0.2547
# Epoch 153/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.3228 - iou_metric: 0.3589 - val_loss: 6.9430 - val_iou_metric: 0.2595
# Epoch 154/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.2161 - iou_metric: 0.3330 - val_loss: 7.2840 - val_iou_metric: 0.2255
# Epoch 155/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.9928 - iou_metric: 0.3053 - val_loss: 7.0426 - val_iou_metric: 0.2325
# Epoch 156/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.5343 - iou_metric: 0.3434 - val_loss: 6.5726 - val_iou_metric: 0.2552
# Epoch 157/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.9947 - iou_metric: 0.3431 - val_loss: 6.3918 - val_iou_metric: 0.2602
# Epoch 158/400
# 5/5 [==============================] - 1s 110ms/step - loss: 4.2153 - iou_metric: 0.3069 - val_loss: 6.5724 - val_iou_metric: 0.2332
# Epoch 159/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.7845 - iou_metric: 0.3399 - val_loss: 6.4241 - val_iou_metric: 0.2569
# Epoch 160/400
# 5/5 [==============================] - 1s 108ms/step - loss: 4.4349 - iou_metric: 0.3279 - val_loss: 6.3653 - val_iou_metric: 0.2755
# Epoch 161/400
# 5/5 [==============================] - 1s 109ms/step - loss: 4.2204 - iou_metric: 0.3208 - val_loss: 6.4936 - val_iou_metric: 0.2726
# Epoch 162/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.9268 - iou_metric: 0.3387 - val_loss: 6.5870 - val_iou_metric: 0.2611
# Epoch 163/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.7545 - iou_metric: 0.3194 - val_loss: 6.4490 - val_iou_metric: 0.2484
# Epoch 164/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.2235 - iou_metric: 0.3380 - val_loss: 6.5300 - val_iou_metric: 0.2406
# Epoch 165/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.5668 - iou_metric: 0.3155 - val_loss: 6.5191 - val_iou_metric: 0.2479
# Epoch 166/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.3049 - iou_metric: 0.3748 - val_loss: 6.4402 - val_iou_metric: 0.2576
# Epoch 167/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.5774 - iou_metric: 0.3414 - val_loss: 6.4639 - val_iou_metric: 0.2509
# Epoch 168/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.3227 - iou_metric: 0.3571 - val_loss: 6.5425 - val_iou_metric: 0.2381
# Epoch 169/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.2333 - iou_metric: 0.3349 - val_loss: 6.7242 - val_iou_metric: 0.2289
# Epoch 170/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.8982 - iou_metric: 0.3213 - val_loss: 6.5280 - val_iou_metric: 0.2460
# Epoch 171/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.4051 - iou_metric: 0.3548 - val_loss: 6.2940 - val_iou_metric: 0.2787
# Epoch 172/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.2444 - iou_metric: 0.3568 - val_loss: 6.3930 - val_iou_metric: 0.2776
# Epoch 173/400
# 5/5 [==============================] - 1s 109ms/step - loss: 3.4444 - iou_metric: 0.3649 - val_loss: 6.3984 - val_iou_metric: 0.2682
# Epoch 174/400
# 5/5 [==============================] - 1s 109ms/step - loss: 3.9719 - iou_metric: 0.3527 - val_loss: 6.2669 - val_iou_metric: 0.2604
# Epoch 175/400
# 5/5 [==============================] - 1s 117ms/step - loss: 4.4916 - iou_metric: 0.3061 - val_loss: 6.2111 - val_iou_metric: 0.2604
# Epoch 176/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.6642 - iou_metric: 0.3654 - val_loss: 6.6821 - val_iou_metric: 0.2259
# Epoch 177/400
# 5/5 [==============================] - 1s 115ms/step - loss: 4.0836 - iou_metric: 0.3283 - val_loss: 6.7162 - val_iou_metric: 0.2253
# Epoch 178/400
# 5/5 [==============================] - 1s 113ms/step - loss: 4.3347 - iou_metric: 0.3223 - val_loss: 6.3998 - val_iou_metric: 0.2460
# Epoch 179/400
# 5/5 [==============================] - 1s 115ms/step - loss: 4.7211 - iou_metric: 0.3348 - val_loss: 6.4951 - val_iou_metric: 0.2392
# Epoch 180/400
# 5/5 [==============================] - 1s 114ms/step - loss: 4.1667 - iou_metric: 0.3461 - val_loss: 6.4964 - val_iou_metric: 0.2380
# Epoch 181/400
# 5/5 [==============================] - 1s 118ms/step - loss: 3.3486 - iou_metric: 0.3195 - val_loss: 6.1500 - val_iou_metric: 0.2658
# Epoch 182/400
# 5/5 [==============================] - 1s 116ms/step - loss: 4.2633 - iou_metric: 0.3375 - val_loss: 6.1454 - val_iou_metric: 0.2638
# Epoch 183/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.7625 - iou_metric: 0.3419 - val_loss: 6.5437 - val_iou_metric: 0.2441
# Epoch 184/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.7800 - iou_metric: 0.3379 - val_loss: 6.6362 - val_iou_metric: 0.2434
# Epoch 185/400
# 5/5 [==============================] - 1s 118ms/step - loss: 3.6069 - iou_metric: 0.3344 - val_loss: 5.9662 - val_iou_metric: 0.2808
# Epoch 186/400
# 5/5 [==============================] - 1s 118ms/step - loss: 3.6526 - iou_metric: 0.3595 - val_loss: 5.9874 - val_iou_metric: 0.2891
# Epoch 187/400
# 5/5 [==============================] - 1s 118ms/step - loss: 4.5632 - iou_metric: 0.3316 - val_loss: 6.5186 - val_iou_metric: 0.2565
# Epoch 188/400
# 5/5 [==============================] - 1s 118ms/step - loss: 3.5930 - iou_metric: 0.3537 - val_loss: 6.2244 - val_iou_metric: 0.2606
# Epoch 189/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.5230 - iou_metric: 0.3504 - val_loss: 5.7808 - val_iou_metric: 0.2726
# Epoch 190/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.4801 - iou_metric: 0.3408 - val_loss: 5.5633 - val_iou_metric: 0.2654
# Epoch 191/400
# 5/5 [==============================] - 1s 116ms/step - loss: 4.2538 - iou_metric: 0.3357 - val_loss: 5.8424 - val_iou_metric: 0.2477
# Epoch 192/400
# 5/5 [==============================] - 1s 119ms/step - loss: 3.8626 - iou_metric: 0.3291 - val_loss: 5.7243 - val_iou_metric: 0.2677
# Epoch 193/400
# 5/5 [==============================] - 1s 129ms/step - loss: 3.9509 - iou_metric: 0.3507 - val_loss: 5.5280 - val_iou_metric: 0.3025
# Epoch 194/400
# 5/5 [==============================] - 1s 120ms/step - loss: 4.1039 - iou_metric: 0.3452 - val_loss: 5.5660 - val_iou_metric: 0.3034
# Epoch 195/400
# 5/5 [==============================] - 1s 121ms/step - loss: 3.7940 - iou_metric: 0.3602 - val_loss: 5.8481 - val_iou_metric: 0.2765
# Epoch 196/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.4796 - iou_metric: 0.3743 - val_loss: 5.4408 - val_iou_metric: 0.3067
# Epoch 197/400
# 5/5 [==============================] - 1s 118ms/step - loss: 3.2928 - iou_metric: 0.3924 - val_loss: 5.7249 - val_iou_metric: 0.2806
# Epoch 198/400
# 5/5 [==============================] - 1s 120ms/step - loss: 3.5811 - iou_metric: 0.3826 - val_loss: 5.8693 - val_iou_metric: 0.2719
# Epoch 199/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.4821 - iou_metric: 0.3670 - val_loss: 5.8994 - val_iou_metric: 0.2681
# Epoch 200/400
# 5/5 [==============================] - 1s 122ms/step - loss: 3.7163 - iou_metric: 0.3776 - val_loss: 5.4374 - val_iou_metric: 0.2887
# Epoch 201/400
# 5/5 [==============================] - 1s 121ms/step - loss: 3.9644 - iou_metric: 0.3569 - val_loss: 5.2803 - val_iou_metric: 0.2946
# Epoch 202/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.3915 - iou_metric: 0.3871 - val_loss: 5.6076 - val_iou_metric: 0.2797
# Epoch 203/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.8419 - iou_metric: 0.3526 - val_loss: 5.5469 - val_iou_metric: 0.2835
# Epoch 204/400
# 5/5 [==============================] - 1s 120ms/step - loss: 3.3734 - iou_metric: 0.3720 - val_loss: 5.7701 - val_iou_metric: 0.2763
# Epoch 205/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.8637 - iou_metric: 0.3854 - val_loss: 5.8486 - val_iou_metric: 0.2815
# Epoch 206/400
# 5/5 [==============================] - 1s 122ms/step - loss: 3.8090 - iou_metric: 0.3589 - val_loss: 5.7210 - val_iou_metric: 0.2878
# Epoch 207/400
# 5/5 [==============================] - 1s 119ms/step - loss: 3.4404 - iou_metric: 0.3709 - val_loss: 6.0468 - val_iou_metric: 0.2719
# Epoch 208/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.7532 - iou_metric: 0.3690 - val_loss: 5.9191 - val_iou_metric: 0.2831
# Epoch 209/400
# 5/5 [==============================] - 1s 119ms/step - loss: 4.4316 - iou_metric: 0.3661 - val_loss: 5.4861 - val_iou_metric: 0.3067
# Epoch 210/400
# 5/5 [==============================] - 1s 118ms/step - loss: 3.3594 - iou_metric: 0.3784 - val_loss: 5.5971 - val_iou_metric: 0.3007
# Epoch 211/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.5360 - iou_metric: 0.3930 - val_loss: 5.7254 - val_iou_metric: 0.2891
# Epoch 212/400
# 5/5 [==============================] - 1s 122ms/step - loss: 4.3477 - iou_metric: 0.3672 - val_loss: 5.5736 - val_iou_metric: 0.2955
# Epoch 213/400
# 5/5 [==============================] - 1s 114ms/step - loss: 4.1806 - iou_metric: 0.3658 - val_loss: 5.6789 - val_iou_metric: 0.2935
# Epoch 214/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.7099 - iou_metric: 0.3735 - val_loss: 5.5063 - val_iou_metric: 0.3108
# Epoch 215/400
# 5/5 [==============================] - 1s 122ms/step - loss: 3.6048 - iou_metric: 0.3899 - val_loss: 5.3655 - val_iou_metric: 0.3159
# Epoch 216/400
# 5/5 [==============================] - 1s 116ms/step - loss: 4.0458 - iou_metric: 0.3744 - val_loss: 5.5505 - val_iou_metric: 0.3023
# Epoch 217/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.3784 - iou_metric: 0.3748 - val_loss: 5.5558 - val_iou_metric: 0.2979
# Epoch 218/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.6353 - iou_metric: 0.3827 - val_loss: 5.5238 - val_iou_metric: 0.3032
# Epoch 219/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.6021 - iou_metric: 0.3620 - val_loss: 5.5898 - val_iou_metric: 0.3122
# Epoch 220/400
# 5/5 [==============================] - 1s 119ms/step - loss: 3.3910 - iou_metric: 0.3889 - val_loss: 5.8594 - val_iou_metric: 0.3122
# Epoch 221/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.6806 - iou_metric: 0.4005 - val_loss: 6.0829 - val_iou_metric: 0.3069
# Epoch 222/400
# 5/5 [==============================] - 1s 118ms/step - loss: 3.5973 - iou_metric: 0.3742 - val_loss: 5.8109 - val_iou_metric: 0.3223
# Epoch 223/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.6816 - iou_metric: 0.3627 - val_loss: 5.6893 - val_iou_metric: 0.3156
# Epoch 224/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.9657 - iou_metric: 0.3733 - val_loss: 5.7215 - val_iou_metric: 0.2931
# Epoch 225/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.0188 - iou_metric: 0.4114 - val_loss: 5.4471 - val_iou_metric: 0.3058
# Epoch 226/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.9887 - iou_metric: 0.3751 - val_loss: 5.2354 - val_iou_metric: 0.3208
# Epoch 227/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.5698 - iou_metric: 0.3784 - val_loss: 5.2989 - val_iou_metric: 0.3198
# Epoch 228/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.7206 - iou_metric: 0.3713 - val_loss: 5.2397 - val_iou_metric: 0.3181
# Epoch 229/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.3657 - iou_metric: 0.3759 - val_loss: 5.4219 - val_iou_metric: 0.3065
# Epoch 230/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.4618 - iou_metric: 0.3885 - val_loss: 5.6255 - val_iou_metric: 0.3075
# Epoch 231/400
# 5/5 [==============================] - 1s 118ms/step - loss: 4.2681 - iou_metric: 0.3723 - val_loss: 5.7304 - val_iou_metric: 0.3123
# Epoch 232/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.6155 - iou_metric: 0.3936 - val_loss: 5.8586 - val_iou_metric: 0.3057
# Epoch 233/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.2229 - iou_metric: 0.4065 - val_loss: 6.1211 - val_iou_metric: 0.2918
# Epoch 234/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.6304 - iou_metric: 0.3783 - val_loss: 5.9613 - val_iou_metric: 0.3009
# Epoch 235/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.0167 - iou_metric: 0.4180 - val_loss: 5.6032 - val_iou_metric: 0.3150
# Epoch 236/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.9045 - iou_metric: 0.3908 - val_loss: 5.5861 - val_iou_metric: 0.2992
# Epoch 237/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.4073 - iou_metric: 0.3746 - val_loss: 5.7923 - val_iou_metric: 0.2839
# Epoch 238/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.2807 - iou_metric: 0.3674 - val_loss: 5.7581 - val_iou_metric: 0.2866
# Epoch 239/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.7807 - iou_metric: 0.4055 - val_loss: 5.6369 - val_iou_metric: 0.3025
# Epoch 240/400
# 5/5 [==============================] - 1s 121ms/step - loss: 3.1677 - iou_metric: 0.4133 - val_loss: 5.6078 - val_iou_metric: 0.3027
# Epoch 241/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.4089 - iou_metric: 0.3973 - val_loss: 5.6169 - val_iou_metric: 0.2997
# Epoch 242/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.0981 - iou_metric: 0.4298 - val_loss: 5.7324 - val_iou_metric: 0.2916
# Epoch 243/400
# 5/5 [==============================] - 1s 115ms/step - loss: 2.9143 - iou_metric: 0.4344 - val_loss: 5.6222 - val_iou_metric: 0.2959
# Epoch 244/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.4660 - iou_metric: 0.3888 - val_loss: 5.7294 - val_iou_metric: 0.2860
# Epoch 245/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.2479 - iou_metric: 0.4151 - val_loss: 6.0899 - val_iou_metric: 0.2642
# Epoch 246/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.1000 - iou_metric: 0.4112 - val_loss: 5.9962 - val_iou_metric: 0.2743
# Epoch 247/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.8605 - iou_metric: 0.3846 - val_loss: 5.7786 - val_iou_metric: 0.2870
# Epoch 248/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.3547 - iou_metric: 0.3796 - val_loss: 5.3517 - val_iou_metric: 0.3146
# Epoch 249/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.0383 - iou_metric: 0.4197 - val_loss: 5.2758 - val_iou_metric: 0.3103
# Epoch 250/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.2607 - iou_metric: 0.4026 - val_loss: 5.7787 - val_iou_metric: 0.2800
# Epoch 251/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.4348 - iou_metric: 0.3816 - val_loss: 5.9600 - val_iou_metric: 0.2776
# Epoch 252/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.9715 - iou_metric: 0.3780 - val_loss: 5.6375 - val_iou_metric: 0.2992
# Epoch 253/400
# 5/5 [==============================] - 1s 119ms/step - loss: 3.5950 - iou_metric: 0.4074 - val_loss: 5.4057 - val_iou_metric: 0.3101
# Epoch 254/400
# 5/5 [==============================] - 1s 117ms/step - loss: 4.4970 - iou_metric: 0.3649 - val_loss: 5.4311 - val_iou_metric: 0.3091
# Epoch 255/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.7346 - iou_metric: 0.3866 - val_loss: 5.8917 - val_iou_metric: 0.2879
# Epoch 256/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.8425 - iou_metric: 0.3679 - val_loss: 5.3248 - val_iou_metric: 0.3175
# Epoch 257/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.0307 - iou_metric: 0.4178 - val_loss: 5.0617 - val_iou_metric: 0.3318
# Epoch 258/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.5275 - iou_metric: 0.4133 - val_loss: 5.1731 - val_iou_metric: 0.3319
# Epoch 259/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.4556 - iou_metric: 0.4129 - val_loss: 5.7061 - val_iou_metric: 0.3028
# Epoch 260/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.7800 - iou_metric: 0.3807 - val_loss: 5.3842 - val_iou_metric: 0.3245
# Epoch 261/400
# 5/5 [==============================] - 1s 114ms/step - loss: 2.9546 - iou_metric: 0.4429 - val_loss: 5.1001 - val_iou_metric: 0.3374
# Epoch 262/400
# 5/5 [==============================] - 1s 110ms/step - loss: 4.1437 - iou_metric: 0.3841 - val_loss: 5.1500 - val_iou_metric: 0.3406
# Epoch 263/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.7966 - iou_metric: 0.4137 - val_loss: 5.7780 - val_iou_metric: 0.3076
# Epoch 264/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.5317 - iou_metric: 0.4007 - val_loss: 5.6867 - val_iou_metric: 0.3140
# Epoch 265/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.7927 - iou_metric: 0.3712 - val_loss: 5.2373 - val_iou_metric: 0.3327
# Epoch 266/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.6404 - iou_metric: 0.4115 - val_loss: 5.2286 - val_iou_metric: 0.3298
# Epoch 267/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.4401 - iou_metric: 0.4005 - val_loss: 5.3196 - val_iou_metric: 0.3204
# Epoch 268/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.4870 - iou_metric: 0.4114 - val_loss: 5.2219 - val_iou_metric: 0.3197
# Epoch 269/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.3858 - iou_metric: 0.4039 - val_loss: 5.0340 - val_iou_metric: 0.3238
# Epoch 270/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.4472 - iou_metric: 0.3870 - val_loss: 4.9122 - val_iou_metric: 0.3361
# Epoch 271/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.5247 - iou_metric: 0.4131 - val_loss: 5.1995 - val_iou_metric: 0.3184
# Epoch 272/400
# 5/5 [==============================] - 1s 115ms/step - loss: 2.9656 - iou_metric: 0.4279 - val_loss: 5.5429 - val_iou_metric: 0.2984
# Epoch 273/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.6898 - iou_metric: 0.3932 - val_loss: 5.4153 - val_iou_metric: 0.3077
# Epoch 274/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.3386 - iou_metric: 0.4057 - val_loss: 5.0890 - val_iou_metric: 0.3405
# Epoch 275/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.4355 - iou_metric: 0.4002 - val_loss: 5.1686 - val_iou_metric: 0.3305
# Epoch 276/400
# 5/5 [==============================] - 1s 118ms/step - loss: 3.6184 - iou_metric: 0.3785 - val_loss: 5.6330 - val_iou_metric: 0.2948
# Epoch 277/400
# 5/5 [==============================] - 1s 119ms/step - loss: 3.1073 - iou_metric: 0.4146 - val_loss: 5.6400 - val_iou_metric: 0.2965
# Epoch 278/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.2214 - iou_metric: 0.3882 - val_loss: 5.2816 - val_iou_metric: 0.3224
# Epoch 279/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.2427 - iou_metric: 0.3958 - val_loss: 5.0821 - val_iou_metric: 0.3275
# Epoch 280/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.6000 - iou_metric: 0.4053 - val_loss: 5.0395 - val_iou_metric: 0.3281
# Epoch 281/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.3437 - iou_metric: 0.4204 - val_loss: 5.4625 - val_iou_metric: 0.3046
# Epoch 282/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.4471 - iou_metric: 0.4255 - val_loss: 5.3046 - val_iou_metric: 0.3158
# Epoch 283/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.7212 - iou_metric: 0.4115 - val_loss: 5.2711 - val_iou_metric: 0.3252
# Epoch 284/400
# 5/5 [==============================] - 1s 122ms/step - loss: 3.5643 - iou_metric: 0.4113 - val_loss: 5.2031 - val_iou_metric: 0.3310
# Epoch 285/400
# 5/5 [==============================] - 1s 116ms/step - loss: 2.9945 - iou_metric: 0.4035 - val_loss: 5.6294 - val_iou_metric: 0.2932
# Epoch 286/400
# 5/5 [==============================] - 1s 117ms/step - loss: 2.9523 - iou_metric: 0.4107 - val_loss: 5.6741 - val_iou_metric: 0.2882
# Epoch 287/400
# 5/5 [==============================] - 1s 115ms/step - loss: 4.0964 - iou_metric: 0.3699 - val_loss: 5.1063 - val_iou_metric: 0.3300
# Epoch 288/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.4823 - iou_metric: 0.3949 - val_loss: 5.1014 - val_iou_metric: 0.3319
# Epoch 289/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.3899 - iou_metric: 0.4186 - val_loss: 5.4664 - val_iou_metric: 0.3062
# Epoch 290/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.7239 - iou_metric: 0.3904 - val_loss: 5.2053 - val_iou_metric: 0.3230
# Epoch 291/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.1218 - iou_metric: 0.4132 - val_loss: 5.0231 - val_iou_metric: 0.3308
# Epoch 292/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.1741 - iou_metric: 0.4270 - val_loss: 5.0318 - val_iou_metric: 0.3305
# Epoch 293/400
# 5/5 [==============================] - ETA: 0s - loss: 3.4687 - iou_metric: 0.42 - 1s 114ms/step - loss: 3.4687 - iou_metric: 0.4284 - val_loss: 5.7550 - val_iou_metric: 0.2876
# Epoch 294/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.2650 - iou_metric: 0.4120 - val_loss: 5.5813 - val_iou_metric: 0.2913
# Epoch 295/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.3524 - iou_metric: 0.4166 - val_loss: 4.7276 - val_iou_metric: 0.3403
# Epoch 296/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.6848 - iou_metric: 0.4120 - val_loss: 4.5664 - val_iou_metric: 0.3478
# Epoch 297/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.3965 - iou_metric: 0.4194 - val_loss: 5.0303 - val_iou_metric: 0.3246
# Epoch 298/400
# 5/5 [==============================] - 1s 109ms/step - loss: 3.2796 - iou_metric: 0.4083 - val_loss: 5.0164 - val_iou_metric: 0.3277
# Epoch 299/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.0292 - iou_metric: 0.4285 - val_loss: 4.7464 - val_iou_metric: 0.3432
# Epoch 300/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.5420 - iou_metric: 0.4094 - val_loss: 5.0100 - val_iou_metric: 0.3318
# Epoch 301/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.5032 - iou_metric: 0.4015 - val_loss: 5.5063 - val_iou_metric: 0.3048
# Epoch 302/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.7018 - iou_metric: 0.4082 - val_loss: 4.9352 - val_iou_metric: 0.3347
# Epoch 303/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.7248 - iou_metric: 0.4105 - val_loss: 4.8888 - val_iou_metric: 0.3318
# Epoch 304/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.3124 - iou_metric: 0.4194 - val_loss: 4.8062 - val_iou_metric: 0.3274
# Epoch 305/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.4007 - iou_metric: 0.4234 - val_loss: 4.8714 - val_iou_metric: 0.3164
# Epoch 306/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.2802 - iou_metric: 0.4165 - val_loss: 5.1342 - val_iou_metric: 0.3059
# Epoch 307/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.9077 - iou_metric: 0.4111 - val_loss: 5.0171 - val_iou_metric: 0.3206
# Epoch 308/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.8463 - iou_metric: 0.3892 - val_loss: 4.9399 - val_iou_metric: 0.3244
# Epoch 309/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.4647 - iou_metric: 0.4285 - val_loss: 5.1770 - val_iou_metric: 0.3085
# Epoch 310/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.3978 - iou_metric: 0.4229 - val_loss: 4.9886 - val_iou_metric: 0.3272
# Epoch 311/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.0614 - iou_metric: 0.4360 - val_loss: 5.0054 - val_iou_metric: 0.3344
# Epoch 312/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.4056 - iou_metric: 0.4259 - val_loss: 4.8950 - val_iou_metric: 0.3446
# Epoch 313/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.7297 - iou_metric: 0.4155 - val_loss: 5.0440 - val_iou_metric: 0.3337
# Epoch 314/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.0530 - iou_metric: 0.4246 - val_loss: 5.3765 - val_iou_metric: 0.3087
# Epoch 315/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.1831 - iou_metric: 0.3958 - val_loss: 5.0497 - val_iou_metric: 0.3279
# Epoch 316/400
# 5/5 [==============================] - 1s 115ms/step - loss: 2.8505 - iou_metric: 0.4166 - val_loss: 4.6914 - val_iou_metric: 0.3447
# Epoch 317/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.8362 - iou_metric: 0.4055 - val_loss: 4.7737 - val_iou_metric: 0.3353
# Epoch 318/400
# 5/5 [==============================] - ETA: 0s - loss: 3.9270 - iou_metric: 0.39 - 1s 113ms/step - loss: 3.9270 - iou_metric: 0.3968 - val_loss: 4.9443 - val_iou_metric: 0.3196
# Epoch 319/400
# 5/5 [==============================] - 1s 117ms/step - loss: 2.8700 - iou_metric: 0.4450 - val_loss: 4.8740 - val_iou_metric: 0.3271
# Epoch 320/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.4044 - iou_metric: 0.4128 - val_loss: 5.0381 - val_iou_metric: 0.3288
# Epoch 321/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.0695 - iou_metric: 0.4396 - val_loss: 5.0884 - val_iou_metric: 0.3331
# Epoch 322/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.0772 - iou_metric: 0.4265 - val_loss: 5.0113 - val_iou_metric: 0.3458
# Epoch 323/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.3690 - iou_metric: 0.4233 - val_loss: 5.3397 - val_iou_metric: 0.3305
# Epoch 324/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.3731 - iou_metric: 0.4437 - val_loss: 5.4289 - val_iou_metric: 0.3156
# Epoch 325/400
# 5/5 [==============================] - 1s 114ms/step - loss: 2.8316 - iou_metric: 0.4418 - val_loss: 4.8746 - val_iou_metric: 0.3409
# Epoch 326/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.3378 - iou_metric: 0.4203 - val_loss: 4.6993 - val_iou_metric: 0.3456
# Epoch 327/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.2664 - iou_metric: 0.4353 - val_loss: 4.8214 - val_iou_metric: 0.3311
# Epoch 328/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.1585 - iou_metric: 0.4232 - val_loss: 5.2009 - val_iou_metric: 0.3083
# Epoch 329/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.2948 - iou_metric: 0.4111 - val_loss: 5.0196 - val_iou_metric: 0.3303
# Epoch 330/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.5465 - iou_metric: 0.4347 - val_loss: 4.6847 - val_iou_metric: 0.3505
# Epoch 331/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.2867 - iou_metric: 0.4513 - val_loss: 4.9145 - val_iou_metric: 0.3300
# Epoch 332/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.6399 - iou_metric: 0.4130 - val_loss: 5.5113 - val_iou_metric: 0.2943
# Epoch 333/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.0527 - iou_metric: 0.4237 - val_loss: 4.8569 - val_iou_metric: 0.3329
# Epoch 334/400
# 5/5 [==============================] - 1s 115ms/step - loss: 2.9034 - iou_metric: 0.4453 - val_loss: 4.5795 - val_iou_metric: 0.3529
# Epoch 335/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.7543 - iou_metric: 0.4319 - val_loss: 4.9610 - val_iou_metric: 0.3243
# Epoch 336/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.4219 - iou_metric: 0.4275 - val_loss: 5.5678 - val_iou_metric: 0.2948
# Epoch 337/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.3992 - iou_metric: 0.4203 - val_loss: 5.1506 - val_iou_metric: 0.3238
# Epoch 338/400
# 5/5 [==============================] - 1s 109ms/step - loss: 2.7305 - iou_metric: 0.4544 - val_loss: 4.9118 - val_iou_metric: 0.3436
# Epoch 339/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.3614 - iou_metric: 0.4266 - val_loss: 5.1392 - val_iou_metric: 0.3278
# Epoch 340/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.2548 - iou_metric: 0.3866 - val_loss: 5.2515 - val_iou_metric: 0.3171
# Epoch 341/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.2360 - iou_metric: 0.4250 - val_loss: 5.1170 - val_iou_metric: 0.3245
# Epoch 342/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.0898 - iou_metric: 0.4246 - val_loss: 4.9047 - val_iou_metric: 0.3386
# Epoch 343/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.2431 - iou_metric: 0.4368 - val_loss: 4.8097 - val_iou_metric: 0.3447
# Epoch 344/400
# 5/5 [==============================] - 1s 116ms/step - loss: 2.9487 - iou_metric: 0.4408 - val_loss: 5.0088 - val_iou_metric: 0.3293
# Epoch 345/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.8539 - iou_metric: 0.4147 - val_loss: 4.7615 - val_iou_metric: 0.3418
# Epoch 346/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.1632 - iou_metric: 0.4308 - val_loss: 4.5561 - val_iou_metric: 0.3494
# Epoch 347/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.5277 - iou_metric: 0.4377 - val_loss: 4.5647 - val_iou_metric: 0.3490
# Epoch 348/400
# 5/5 [==============================] - 1s 112ms/step - loss: 2.9364 - iou_metric: 0.4446 - val_loss: 4.5723 - val_iou_metric: 0.3533
# Epoch 349/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.1150 - iou_metric: 0.4423 - val_loss: 4.6826 - val_iou_metric: 0.3445
# Epoch 350/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.2189 - iou_metric: 0.4289 - val_loss: 4.5822 - val_iou_metric: 0.3463
# Epoch 351/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.4258 - iou_metric: 0.4248 - val_loss: 4.5196 - val_iou_metric: 0.3414
# Epoch 352/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.5930 - iou_metric: 0.4097 - val_loss: 4.5878 - val_iou_metric: 0.3279
# Epoch 353/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.3398 - iou_metric: 0.4317 - val_loss: 4.7237 - val_iou_metric: 0.3202
# Epoch 354/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.3283 - iou_metric: 0.4043 - val_loss: 4.7727 - val_iou_metric: 0.3178
# Epoch 355/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.1274 - iou_metric: 0.4443 - val_loss: 4.7977 - val_iou_metric: 0.3193
# Epoch 356/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.0834 - iou_metric: 0.4207 - val_loss: 4.7918 - val_iou_metric: 0.3241
# Epoch 357/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.4547 - iou_metric: 0.4201 - val_loss: 4.6348 - val_iou_metric: 0.3404
# Epoch 358/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.1013 - iou_metric: 0.4501 - val_loss: 4.7939 - val_iou_metric: 0.3328
# Epoch 359/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.0024 - iou_metric: 0.4491 - val_loss: 5.0824 - val_iou_metric: 0.3208
# Epoch 360/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.7350 - iou_metric: 0.4119 - val_loss: 4.9356 - val_iou_metric: 0.3366
# Epoch 361/400
# 5/5 [==============================] - 1s 116ms/step - loss: 3.5224 - iou_metric: 0.4231 - val_loss: 4.6038 - val_iou_metric: 0.3537
# Epoch 362/400
# 5/5 [==============================] - 1s 112ms/step - loss: 2.9146 - iou_metric: 0.4322 - val_loss: 4.4361 - val_iou_metric: 0.3596
# Epoch 363/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.3044 - iou_metric: 0.4416 - val_loss: 4.3473 - val_iou_metric: 0.3617
# Epoch 364/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.2682 - iou_metric: 0.4385 - val_loss: 4.3941 - val_iou_metric: 0.3571
# Epoch 365/400
# 5/5 [==============================] - 1s 109ms/step - loss: 2.9303 - iou_metric: 0.4564 - val_loss: 4.3769 - val_iou_metric: 0.3552
# Epoch 366/400
# 5/5 [==============================] - 1s 109ms/step - loss: 3.6363 - iou_metric: 0.4175 - val_loss: 4.4346 - val_iou_metric: 0.3484
# Epoch 367/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.1263 - iou_metric: 0.4302 - val_loss: 4.6264 - val_iou_metric: 0.3355
# Epoch 368/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.6887 - iou_metric: 0.4087 - val_loss: 4.9881 - val_iou_metric: 0.3229
# Epoch 369/400
# 5/5 [==============================] - 1s 119ms/step - loss: 3.1622 - iou_metric: 0.4250 - val_loss: 4.8160 - val_iou_metric: 0.3377
# Epoch 370/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.4110 - iou_metric: 0.4380 - val_loss: 4.6903 - val_iou_metric: 0.3529
# Epoch 371/400
# 5/5 [==============================] - 1s 112ms/step - loss: 2.8878 - iou_metric: 0.4694 - val_loss: 4.7439 - val_iou_metric: 0.3458
# Epoch 372/400
# 5/5 [==============================] - 1s 112ms/step - loss: 3.0842 - iou_metric: 0.4342 - val_loss: 4.7306 - val_iou_metric: 0.3375
# Epoch 373/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.6508 - iou_metric: 0.4185 - val_loss: 4.7563 - val_iou_metric: 0.3330
# Epoch 374/400
# 5/5 [==============================] - 1s 113ms/step - loss: 2.9913 - iou_metric: 0.4473 - val_loss: 4.7193 - val_iou_metric: 0.3298
# Epoch 375/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.3302 - iou_metric: 0.4384 - val_loss: 4.4224 - val_iou_metric: 0.3465
# Epoch 376/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.5343 - iou_metric: 0.4324 - val_loss: 4.3680 - val_iou_metric: 0.3509
# Epoch 377/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.4663 - iou_metric: 0.4223 - val_loss: 4.4850 - val_iou_metric: 0.3427
# Epoch 378/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.5040 - iou_metric: 0.4390 - val_loss: 4.4550 - val_iou_metric: 0.3494
# Epoch 379/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.5279 - iou_metric: 0.4214 - val_loss: 4.4471 - val_iou_metric: 0.3497
# Epoch 380/400
# 5/5 [==============================] - 1s 118ms/step - loss: 3.5785 - iou_metric: 0.4219 - val_loss: 4.4321 - val_iou_metric: 0.3460
# Epoch 381/400
# 5/5 [==============================] - 1s 110ms/step - loss: 3.3618 - iou_metric: 0.4237 - val_loss: 4.6196 - val_iou_metric: 0.3371
# Epoch 382/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.4711 - iou_metric: 0.4276 - val_loss: 4.5460 - val_iou_metric: 0.3479
# Epoch 383/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.1767 - iou_metric: 0.4141 - val_loss: 4.5284 - val_iou_metric: 0.3541
# Epoch 384/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.1913 - iou_metric: 0.4379 - val_loss: 4.6830 - val_iou_metric: 0.3464
# Epoch 385/400
# 5/5 [==============================] - 1s 119ms/step - loss: 3.5888 - iou_metric: 0.4332 - val_loss: 4.6770 - val_iou_metric: 0.3446
# Epoch 386/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.6852 - iou_metric: 0.4267 - val_loss: 4.5400 - val_iou_metric: 0.3504
# Epoch 387/400
# 5/5 [==============================] - 1s 117ms/step - loss: 3.1117 - iou_metric: 0.4397 - val_loss: 4.5336 - val_iou_metric: 0.3509
# Epoch 388/400
# 5/5 [==============================] - 1s 119ms/step - loss: 3.6292 - iou_metric: 0.4324 - val_loss: 4.7232 - val_iou_metric: 0.3395
# Epoch 389/400
# 5/5 [==============================] - 1s 113ms/step - loss: 2.9316 - iou_metric: 0.4425 - val_loss: 4.7601 - val_iou_metric: 0.3346
# Epoch 390/400
# 5/5 [==============================] - 1s 118ms/step - loss: 3.5910 - iou_metric: 0.4421 - val_loss: 4.5111 - val_iou_metric: 0.3473
# Epoch 391/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.0572 - iou_metric: 0.4668 - val_loss: 4.3310 - val_iou_metric: 0.3546
# Epoch 392/400
# 5/5 [==============================] - 1s 111ms/step - loss: 2.8171 - iou_metric: 0.4734 - val_loss: 4.3098 - val_iou_metric: 0.3532
# Epoch 393/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.4515 - iou_metric: 0.4559 - val_loss: 4.4176 - val_iou_metric: 0.3464
# Epoch 394/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.1647 - iou_metric: 0.4712 - val_loss: 4.5582 - val_iou_metric: 0.3373
# Epoch 395/400
# 5/5 [==============================] - 1s 111ms/step - loss: 3.4162 - iou_metric: 0.4371 - val_loss: 4.6356 - val_iou_metric: 0.3387
# Epoch 396/400
# 5/5 [==============================] - 1s 114ms/step - loss: 3.0615 - iou_metric: 0.4548 - val_loss: 4.7373 - val_iou_metric: 0.3377
# Epoch 397/400
# 5/5 [==============================] - 1s 116ms/step - loss: 2.8367 - iou_metric: 0.4528 - val_loss: 4.8949 - val_iou_metric: 0.3239
# Epoch 398/400
# 5/5 [==============================] - 1s 115ms/step - loss: 3.3107 - iou_metric: 0.4439 - val_loss: 4.6927 - val_iou_metric: 0.3339
# Epoch 399/400
# 5/5 [==============================] - 1s 114ms/step - loss: 2.9600 - iou_metric: 0.4624 - val_loss: 4.6016 - val_iou_metric: 0.3437
# Epoch 400/400
# 5/5 [==============================] - 1s 113ms/step - loss: 3.0690 - iou_metric: 0.4334 - val_loss: 4.5434 - val_iou_metric: 0.3484

# %%
# Visualising model performance

loss = history.history['loss']
val_loss = history.history['val_loss']

acc = history.history['iou_metric']
val_acc = history.history['val_iou_metric']

plt.figure(figsize=(10,15))
plt.subplot(2,1,1)
plt.plot(loss , linewidth=3 ,label='train loss')
plt.plot(val_loss , linewidth=3, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss / val_loss')
plt.legend()

plt.subplot(2,1,2)
plt.plot(acc , linewidth=3 ,label='train acc')
plt.plot(val_acc , linewidth=3, label='val acc')
plt.xlabel('epochs')
plt.ylabel('Accuracy / Val_Accuracy')
plt.legend()

# %%
# Understanding model performance

predict = new_model.predict(test_features_vec)
predbox = predict[...,0:4] * 224         # denormalisation
groundtruth = val_labels[...,0:4] * 224

# %%
# Function to find IOU (to be used while plotting)

def bb_iou(boxA, boxB):
    # determine the (x, y)-coordinates of the intersection rectangle
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    
    # compute the area of intersection rectangle
    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    
    # compute the area of both the prediction and ground-truth
    boxAArea = (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
    boxBArea = (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)
    
    # compute the intersection over union by taking the intersection
    # area and dividing it by the sum of prediction + ground-truth
    # areas - the interesection area
    iou = interArea / float(boxAArea + boxBArea - interArea)
    return iou

# %%
# Visualising relatively better detection predictions

for i in range(len(test)):
    if bb_iou(groundtruth[i], predbox[i]) > 0.35:
        data = im.imread(test.Images[i])

        start_point = (int(predbox[i][0]), int(predbox[i][1]))               # (xmin, ymin)
        end_point = (int(predbox[i][2]), int(predbox[i][3]))                 # (xmax, ymax)
        a_start_point = (int(groundtruth[i][0]), int(groundtruth[i][1]))     # (xmin, ymin)
        a_end_point = (int(groundtruth[i][2]), int(groundtruth[i][3]))    

        color = (255, 0, 0)       # RGB
        a_color = (0, 0, 255)                       
        
        if data.shape[0] < 300:
            thickness = 3
        else:
            thickness = 9
        
        data = cv2.rectangle(data, start_point, end_point, color, thickness)
        data = cv2.rectangle(data, a_start_point, a_end_point, a_color, thickness)
        
        plt.imshow(data)
        plt.show()

# %%
# Visualising mispredictions

count = 0

for i in range(len(test)):
    if bb_iou(groundtruth[i], predbox[i]) == 0 and count < 5:
        data = im.imread(test.Images[i])

        start_point = (int(predbox[i][0]), int(predbox[i][1]))               # (xmin, ymin)
        end_point = (int(predbox[i][2]), int(predbox[i][3]))                 # (xmax, ymax)
        a_start_point = (int(groundtruth[i][0]), int(groundtruth[i][1]))     # (xmin, ymin)
        a_end_point = (int(groundtruth[i][2]), int(groundtruth[i][3]))    

        color = (255, 0, 0)       # RGB
        a_color = (0, 0, 255)                       
        
        if data.shape[0] < 250:
            thickness = 3
        else:
            thickness = 9
        
        data = cv2.rectangle(data, start_point, end_point, color, thickness)
        data = cv2.rectangle(data, a_start_point, a_end_point, a_color, thickness)
        count += 1
        
        plt.imshow(data)
        plt.show()
